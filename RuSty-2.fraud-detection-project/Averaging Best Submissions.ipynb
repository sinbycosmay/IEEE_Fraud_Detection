# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/xgbest/xgb_2.csv
# /kaggle/input/xgbest/xgb_1.csv
# /kaggle/input/final-submissions/submission_avg.csv
# /kaggle/input/final-submissions/submission_powavg.csv
# /kaggle/input/final-submissions/Full AUC score 0.962929.csv

# %%
s1 = pd.read_csv('../input/final-submissions/Full AUC score 0.962929.csv', index_col='TransactionID')
s2 = pd.read_csv('../input/final-submissions/submission_avg.csv', index_col='TransactionID')
s3 = pd.read_csv('../input/final-submissions/submission_powavg.csv', index_col='TransactionID')

# %%
s1

# %%
s4 = (s1 + s2)/2

# %%
s4.to_csv('avg_1.csv')

# %%
s5 = (s2+s3)/2
s5.to_csv('avg_2.csv')

# %%
s6 = (s1+s3)/2
s6.to_csv('avg_3.csv')

# %%
s7 = (s1+s2+s3)/3
s7.to_csv('avg_4.csv')

# %%
# s4, s6, s7

# %%
s8 = (s4+s6)/2
s8.to_csv('avg_5.csv')

# %%
s9 = (s7+s6)/2
s9.to_csv('avg_6.csv')

# %%
s10 = (s4+s7)/2
s10.to_csv('avg_7.csv')

# %%
s11 = (s4 + s6 + s7)/3
s11.to_csv('avg_8.csv')

# %%
#s8, s9, s6

# %%
s12 = (s8+s6)/2
s12.to_csv('avg_9.csv')

# %%
s13 = (s9+s6)/2
s13.to_csv('avg_10.csv')

# %%
s14 = (s8+s9)/2
s14.to_csv('avg_11.csv')

# %%
s15 = (s8 + s6 + s9)/3
s15.to_csv('avg_12.csv')

# %%
#s6, s12, s13

# %%
s16 = (s12+s6)/2
s16.to_csv('avg_13.csv')

s17 = (s13+s6)/2
s17.to_csv('avg_14.csv')

s18 = (s12+s13)/2
s18.to_csv('avg_15.csv')

s19 = (s12 + s6 + s13)/3
s19.to_csv('avg_16.csv')

# %%
s19 = (s12 + s6 + s13)/3
s19.to_csv('avg_16.csv')

# %%
#s16, s17, s6

# %%
s20 = (s16+s6)/2
s20.to_csv('avg_17.csv')

s21 = (s17+s6)/2
s21.to_csv('avg_18.csv')

s22 = (s16+s17)/2
s22.to_csv('avg_19.csv')

s23 = (s16 + s6 + s17)/3
s23.to_csv('avg_20.csv')

# %%
#s20, s21, s6

# %%
s24 = (s20+s6)/2
s24.to_csv('avg_21.csv')

s25 = (s21+s6)/2
s25.to_csv('avg_22.csv')

s26 = (s21+s20)/2
s26.to_csv('avg_23.csv')

s27 = (s21 + s6 + s20)/3
s27.to_csv('avg_24.csv')

# %%
#s25, s26, s27

# %%
s28 = (s25+s26)/2
s28.to_csv('avg_25.csv')

s29 = (s27+s26)/2
s29.to_csv('avg_26.csv')

s30 = (s25+s27)/2
s30.to_csv('avg_27.csv')

s31 = (s25 + s26 + s27)/3
s31.to_csv('avg_28.csv')

# %%
x1 = pd.read_csv('../input/xgbest/xgb_1.csv', index_col='TransactionID')
x2 = pd.read_csv('../input/xgbest/xgb_2.csv', index_col='TransactionID')
p1 = pd.read_csv('../input/xgbest/submission_37.csv', index_col='TransactionID')

# %%
a1 = (x1+x2)/2
a1.to_csv('lol_1.csv')

a2 = (x1+p1)/2
a2.to_csv('lol_2.csv')

a3 = (x2+p1)/2
a3.to_csv('lol_3.csv')

a4 = (x1 + x2 + p1)/3
a4.to_csv('lol_4.csv')

# %%
# a4, a1, a2

# %%
x1 = a4
x2 = a1
p1 = a2

# %%
a5 = (x1+x2)/2
a5.to_csv('lol_5.csv')

a6 = (x1+p1)/2
a6.to_csv('lol_6.csv')

a7 = (x2+p1)/2
a7.to_csv('lol_7.csv')

a8 = (x1 + x2 + p1)/3
a8.to_csv('lol_8.csv')

# %%
# a7, a8, a4

# %%
x1 = a7
x2 = a8
p1 = a4

# %%
a9 = (x1+x2)/2
a9.to_csv('lol_9.csv')

a10 = (x1+p1)/2
a10.to_csv('lol_10.csv')

a11 = (x2+p1)/2
a11.to_csv('lol_11.csv')

a12 = (x1 + x2 + p1)/3
a12.to_csv('lol_12.csv')

# %%
a8
# Out:
#                 isFraud
# TransactionID
# 2987000        0.011002
# 2987001        0.011303
# 2987004        0.000781
# 2987007        0.457507
# 2987009        0.001854
# ...                 ...
# 3577532        0.000474
# 3577533        0.136315
# 3577534        0.012179
# 3577535        0.002351
# 3577536        0.004567
#
# [236216 rows x 1 columns]

# %%
a12
# Out:
#                 isFraud
# TransactionID
# 2987000        0.011045
# 2987001        0.011204
# 2987004        0.000771
# 2987007        0.454248
# 2987009        0.001847
# ...                 ...
# 3577532        0.000472
# 3577533        0.134596
# 3577534        0.011942
# 3577535        0.002337
# 3577536        0.004600
#
# [236216 rows x 1 columns]
